# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
htmlFile = '/Users/Pedro/Desktop/Fordham/python/Labs/GoodReads.html'

# %%
url = 'https://www.goodreads.com/list/show/143500.Best_Books_of_the_Decade_2020_s'
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

# %%
with open(htmlFile, 'w', encoding = 'utf8') as file:
     file.write(soup.prettify())

# %%
with open(htmlFile, 'r', encoding = 'utf8') as file:
    html = file.read()
    soup = BeautifulSoup(html, 'html.parser')

# %%
bookList = []
books = soup.find_all(itemtype = 'http://schema.org/Book')

# %%
books
# Out:
# [<tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             1
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="50623864">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="50623864" data-resource-type="Book">
#  <a href="/book/show/50623864-the-invisible-life-of-addie-larue" title="The Invisible Life of Addie LaRue">
#  <img alt="The Invisible Life of Addie..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1584633432i/50623864._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/50623864-the-invisible-life-of-addie-larue" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               The Invisible Life of Addie LaRue
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/7168230.V_E_Schwab" itemprop="url">
#  <span itemprop="name">
#                 V.E. Schwab
#                </span>
#  </a>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.22 avg rating — 789,208 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 20,602
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_788899" onclick="new Ajax.Request('/list/list_book/9798124', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_788899');$('loading_link_788899').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_788899').show();;Element.hide('loading_anim_788899');}, onLoading:function(request){;Element.show('loading_anim_788899');Element.hide('loading_link_788899')}, onSuccess:function(request){Element.hide('loading_anim_788899');Element.show('loading_link_788899');}, parameters:'authenticity_token=' + encodeURIComponent('cxhije29P9PrR7gF6ysrA6+VqHWgmhaVN+KdLc9qJ3piBs6ADD++MBnG2ueM3w9ANWLDcVUWLhovyuR18zQ8XA==')}); return false;">
#                208 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_788899" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="1_book_50623864">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="Syc4WeijvdaD5HYau8Nw9WBF44pPhO5NI2+feuWx1G1aOZRUCSE8NXFlFPjcN1S2+rKIjroI1sI7R+Yi2e/PSw=="/>
#  <input id="book_id" name="book_id" type="hidden" value="50623864"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="1_book_50623864"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="TPwosXWyi6/PJCKtIieEz5T71G9O2GfOp7jkGptweLld4oS8lDAKTD2lQE9F06CMDgy/a7tUX0G/kJ1Cpy5jnw=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="1_book_50623864"/>
#  <input id="book_id" name="book_id" type="hidden" value="50623864"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  <div class="wtrShelfMenu">
#  <ul class="wtrExclusiveShelves">
#  <li>
#  <button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
#  <span class="progressTrigger">
#                    Want to Read
#                   </span>
#  <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
#  </button>
#  </li>
#  <li>
#  <button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
#  <span class="progressTrigger">
#                    Currently Reading
#                   </span>
#  <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
#  </button>
#  </li>
#  <li>
#  <button class="wtrExclusiveShelf" name="name" type="submit" value="read">
#  <span class="progressTrigger">
#                    Read
#                   </span>
#  <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
#  </button>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="50623864" data-restore-rating="null" data-submit-url="/review/rate/50623864?stars_click=true&amp;wtr_button_id=1_book_50623864" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             2
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="52578297">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="52578297" data-resource-type="Book">
#  <a href="/book/show/52578297-the-midnight-library" title="The Midnight Library">
#  <img alt="The Midnight Library" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1602190253i/52578297._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/52578297-the-midnight-library" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               The Midnight Library
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/76360.Matt_Haig" itemprop="url">
#  <span itemprop="name">
#                 Matt Haig
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.02 avg rating — 1,287,332 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 14,659
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_294412" onclick="new Ajax.Request('/list/list_book/11025263', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_294412');$('loading_link_294412').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_294412').show();;Element.hide('loading_anim_294412');}, onLoading:function(request){;Element.show('loading_anim_294412');Element.hide('loading_link_294412')}, onSuccess:function(request){Element.hide('loading_anim_294412');Element.show('loading_link_294412');}, parameters:'authenticity_token=' + encodeURIComponent('n79EU3Jam/QZOVfatWYRaNi2eSSnLzezSQNqr4FWCayOoehek9gaF+u4NTjSkjUrQkESIFKjDzxRKxP3vQgSig==')}); return false;">
#                149 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_294412" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="2_book_52578297">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="uNnylePyf6lXJvoBqa3SiA842FOrOy1rzz73GeQY1TOpx16YAnD+SqWnmOPOWfbLlc+zV163FeTXFo5B2EbOFQ=="/>
#  <input id="book_id" name="book_id" type="hidden" value="52578297"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="2_book_52578297"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="VBqp9xuk8uBwDfxDg8Rz0riewC2o2YGhBSbnhDwL4lhFBAX6+iZzA4KMnqHkMFeRImmrKV1VuS4dDp7cAFX5fg=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="2_book_52578297"/>
#  <input id="book_id" name="book_id" type="hidden" value="52578297"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="52578297" data-restore-rating="null" data-submit-url="/review/rate/52578297?stars_click=true&amp;wtr_button_id=2_book_52578297" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             3
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="45047384">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="45047384" data-resource-type="Book">
#  <a href="/book/show/45047384-the-house-in-the-cerulean-sea" title="The House in the Cerulean Sea">
#  <img alt="The House in the Cerulean Sea" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1569514209i/45047384._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/45047384-the-house-in-the-cerulean-sea" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               The House in the Cerulean Sea
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/5073330.T_J_Klune" itemprop="url">
#  <span itemprop="name">
#                 T.J. Klune
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.44 avg rating — 420,876 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 14,022
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_170370" onclick="new Ajax.Request('/list/list_book/10272142', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_170370');$('loading_link_170370').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_170370').show();;Element.hide('loading_anim_170370');}, onLoading:function(request){;Element.show('loading_anim_170370');Element.hide('loading_link_170370')}, onSuccess:function(request){Element.hide('loading_anim_170370');Element.show('loading_link_170370');}, parameters:'authenticity_token=' + encodeURIComponent('O8FwAhH/RyY1PpQmHD+yIXHwKjpur8aHJ9g8l3BfzDcq39wP8H3Gxce/9sR7y5Zi6wdBPpsj/gg/8EXPTAHXEQ==')}); return false;">
#                142 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_170370" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="3_book_45047384">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="X5bKL9aZ+SxrYtmWVlbmH29V4mLRJrXyTz+PGlvsQRNOiGYiNxt4z5nju3QxosJc9aKJZiSqjX1XF/ZCZ7JaNQ=="/>
#  <input id="book_id" name="book_id" type="hidden" value="45047384"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="3_book_45047384"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="laQBoADxStpRzWJfLh24ht36BY01bgxRShgLTLc+VTKEuq2t4XPLOaNMAL1J6ZzFRw1uicDiNN5SMHIUi2BOFA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="3_book_45047384"/>
#  <input id="book_id" name="book_id" type="hidden" value="45047384"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="45047384" data-restore-rating="null" data-submit-url="/review/rate/45047384?stars_click=true&amp;wtr_button_id=3_book_45047384" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             4
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="51791252">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="51791252" data-resource-type="Book">
#  <a href="/book/show/51791252-the-vanishing-half" title="The Vanishing Half">
#  <img alt="The Vanishing Half" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1577090827l/51791252._SX50_SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/51791252-the-vanishing-half" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               The Vanishing Half
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/10802967.Brit_Bennett" itemprop="url">
#  <span itemprop="name">
#                 Brit Bennett
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.17 avg rating — 655,738 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 10,682
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_424068" onclick="new Ajax.Request('/list/list_book/9749953', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_424068');$('loading_link_424068').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_424068').show();;Element.hide('loading_anim_424068');}, onLoading:function(request){;Element.show('loading_anim_424068');Element.hide('loading_link_424068')}, onSuccess:function(request){Element.hide('loading_anim_424068');Element.show('loading_link_424068');}, parameters:'authenticity_token=' + encodeURIComponent('6CVtdx1QVkq0E6FLKu6gMBfWqk/Gs/KAx+1RLieArPX5O8F6/NLXqUaSw6lNGoRzjSHBSzM/yg/fxSh2G9630w==')}); return false;">
#                110 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_424068" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="4_book_51791252">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="HZfnEtasEtDgg6uPF45yMRRb93nwKDW5gz/dmigGiaEMiUsfNy6TMxICyW1welZyjqycfQWkDTabF6TCFFiShw=="/>
#  <input id="book_id" name="book_id" type="hidden" value="51791252"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="4_book_51791252"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="1JHyM48UF8mUBY9+E6oTsfwCIPJd1vxLckK5UBoP9HbFj14+bpaWKmaE7Zx0XjfyZvVL9qhaxMRqasAIJlHvUA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="4_book_51791252"/>
#  <input id="book_id" name="book_id" type="hidden" value="51791252"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="51791252" data-restore-rating="null" data-submit-url="/review/rate/51791252?stars_click=true&amp;wtr_button_id=4_book_51791252" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             5
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="44890081">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="44890081" data-resource-type="Book">
#  <a href="/book/show/44890081-my-dark-vanessa" title="My Dark Vanessa">
#  <img alt="My Dark Vanessa" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1583447793i/44890081._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/44890081-my-dark-vanessa" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               My Dark Vanessa
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/18692517.Kate_Elizabeth_Russell" itemprop="url">
#  <span itemprop="name">
#                 Kate Elizabeth Russell
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.09 avg rating — 247,963 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 10,225
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_188397" onclick="new Ajax.Request('/list/list_book/9272830', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_188397');$('loading_link_188397').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_188397').show();;Element.hide('loading_anim_188397');}, onLoading:function(request){;Element.show('loading_anim_188397');Element.hide('loading_link_188397')}, onSuccess:function(request){Element.hide('loading_anim_188397');Element.show('loading_link_188397');}, parameters:'authenticity_token=' + encodeURIComponent('CLrbImEJqrA2zN41zMXWsvqNxP1Sqq5Tua9YE9c8IAIZpHcvgIsrU8RNvNerMfLxYHqv+acmltyhhyFL62I7JA==')}); return false;">
#                104 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_188397" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="5_book_44890081">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="lwMwxe1TLVOVefEKhvW4RArgHLbbhndTkf/9PsdaP6SGHZzIDNGssGf4k+jhAZwHkBd3si4KT9yJ14Rm+wQkgg=="/>
#  <input id="book_id" name="book_id" type="hidden" value="44890081"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="5_book_44890081"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="prfOOdIeQIwmae8a6d/UlMMpXDeaLS02r8o6TSOUIz23qWI0M5zBb9TojfiOK/DXWd43M2+hFbm34kMVH8o4Gw=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="5_book_44890081"/>
#  <input id="book_id" name="book_id" type="hidden" value="44890081"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="44890081" data-restore-rating="null" data-submit-url="/review/rate/44890081?stars_click=true&amp;wtr_button_id=5_book_44890081" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             6
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="54493401">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="54493401" data-resource-type="Book">
#  <a href="/book/show/54493401-project-hail-mary" title="Project Hail Mary">
#  <img alt="Project Hail Mary" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1597695864i/54493401._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/54493401-project-hail-mary" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               Project Hail Mary
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/6540057.Andy_Weir" itemprop="url">
#  <span itemprop="name">
#                 Andy Weir
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p6" size="12x12">
#  </span>
#  </span>
#                4.52 avg rating — 389,656 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 9,850
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_381057" onclick="new Ajax.Request('/list/list_book/10955124', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_381057');$('loading_link_381057').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_381057').show();;Element.hide('loading_anim_381057');}, onLoading:function(request){;Element.show('loading_anim_381057');Element.hide('loading_link_381057')}, onSuccess:function(request){Element.hide('loading_anim_381057');Element.show('loading_link_381057');}, parameters:'authenticity_token=' + encodeURIComponent('9Kw2kKRPbPC/LEMTnu2Nc49A9TGlJm1Gt+pjQunyTBvlspqdRc3tE02tIfH5GakwFbeeNVCqVcmvwhoa1axXPQ==')}); return false;">
#                100 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_381057" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="6_book_54493401">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="9qizVFYPxcKIucejLjkahY7PKklo6BVvCkQdJEZdY0Lnth9Zt41EIXo4pUFJzT7GFDhBTZ1kLeASbGR8egN4ZA=="/>
#  <input id="book_id" name="book_id" type="hidden" value="54493401"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="6_book_54493401"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="IMqPAi4mOGBb+BPzP9jB6fL/3T4MPBa/tiCww9eDlaox1CMPz6S5g6l5cRFYLOWqaAi2OvmwLjCuCMmb692OjA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="6_book_54493401"/>
#  <input id="book_id" name="book_id" type="hidden" value="54493401"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="54493401" data-restore-rating="null" data-submit-url="/review/rate/54493401?stars_click=true&amp;wtr_button_id=6_book_54493401" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             7
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="44778083">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="44778083" data-resource-type="Book">
#  <a href="/book/show/44778083-house-of-earth-and-blood" title="House of Earth and Blood">
#  <img alt="House of Earth and Blood (C..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1559142847i/44778083._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/44778083-house-of-earth-and-blood" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               House of Earth and Blood (Crescent City, #1)
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/3433047.Sarah_J_Maas" itemprop="url">
#  <span itemprop="name">
#                 Sarah J. Maas
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.48 avg rating — 363,621 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 8,427
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_469320" onclick="new Ajax.Request('/list/list_book/9521562', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_469320');$('loading_link_469320').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_469320').show();;Element.hide('loading_anim_469320');}, onLoading:function(request){;Element.show('loading_anim_469320');Element.hide('loading_link_469320')}, onSuccess:function(request){Element.hide('loading_anim_469320');Element.show('loading_link_469320');}, parameters:'authenticity_token=' + encodeURIComponent('WXx8p5ynAfpr373GExdAIl98YAAoG3Hc0sSu4ueIBF5IYtCqfSWAGZle3yR042RhxYsLBN2XSVPK7Ne629YfeA==')}); return false;">
#                85 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_469320" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="7_book_44778083">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="a5cKtpeT9g3hGEGH6qS9qVwBgOJ0tinS7/DwyWpZEz56iaa7dhF37hOZI2WNUJnqxvbr5oE6EV332ImRVgcIGA=="/>
#  <input id="book_id" name="book_id" type="hidden" value="44778083"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="7_book_44778083"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="nUGQJInED4OapJ1HCzGutyexgE0yhLrYxdzv2I/YxS6MXzwpaEaOYGgl/6VsxYr0vUbrSccIglfd9JaAs4beCA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="7_book_44778083"/>
#  <input id="book_id" name="book_id" type="hidden" value="44778083"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="44778083" data-restore-rating="null" data-submit-url="/review/rate/44778083?stars_click=true&amp;wtr_button_id=7_book_44778083" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             8
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="50202953">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="50202953" data-resource-type="Book">
#  <a href="/book/show/50202953-piranesi" title="Piranesi">
#  <img alt="Piranesi" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1609095173i/50202953._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/50202953-piranesi" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               Piranesi
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/8842.Susanna_Clarke" itemprop="url">
#  <span itemprop="name">
#                 Susanna Clarke
#                </span>
#  </a>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.24 avg rating — 199,638 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 8,264
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_73310" onclick="new Ajax.Request('/list/list_book/10302560', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_73310');$('loading_link_73310').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_73310').show();;Element.hide('loading_anim_73310');}, onLoading:function(request){;Element.show('loading_anim_73310');Element.hide('loading_link_73310')}, onSuccess:function(request){Element.hide('loading_anim_73310');Element.show('loading_link_73310');}, parameters:'authenticity_token=' + encodeURIComponent('AAvfBcPenr2jLrzmHD8qac0CbcBKMMYtKU5VPuFw50MRFXMIIlwfXlGv3gR7yw4qV/UGxL+8/qIxZixm3S78ZQ==')}); return false;">
#                84 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_73310" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
# ...
#  <img alt="Loading trans" class="loading" id="loading_anim_206345" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="98_book_45134200">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="G80VFKDxqAQBDeLlp3dOe+T8a5E5TwfsGpRKWqBXCqAK07kZQXMp5/OMgAfAg2o4fgsAlczDP2MCvDMCnAkRhg=="/>
#  <input id="book_id" name="book_id" type="hidden" value="45134200"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="98_book_45134200"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="MG1WY0Tffc7+WSOhKKBohSAeJGTiuW+w3+gj6f7Zn74hc/pupV38LQzYQUNPVEzGuulPYBc1Vz/HwFqxwoeEmA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="98_book_45134200"/>
#  <input id="book_id" name="book_id" type="hidden" value="45134200"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="45134200" data-restore-rating="null" data-submit-url="/review/rate/45134200?stars_click=true&amp;wtr_button_id=98_book_45134200" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             99
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="43449920">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="43449920" data-resource-type="Book">
#  <a href="/book/show/43449920-heartstopper" title="Heartstopper: Volume Three">
#  <img alt="Heartstopper: Volume Three ..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1572608363i/43449920._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/43449920-heartstopper" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               Heartstopper: Volume Three (Heartstopper, #3)
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/7789423.Alice_Oseman" itemprop="url">
#  <span itemprop="name">
#                 Alice Oseman
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p6" size="12x12">
#  </span>
#  </span>
#                4.61 avg rating — 325,815 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 764
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_213351" onclick="new Ajax.Request('/list/list_book/11896239', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_213351');$('loading_link_213351').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_213351').show();;Element.hide('loading_anim_213351');}, onLoading:function(request){;Element.show('loading_anim_213351');Element.hide('loading_link_213351')}, onSuccess:function(request){Element.hide('loading_anim_213351');Element.show('loading_link_213351');}, parameters:'authenticity_token=' + encodeURIComponent('x6eqTiDze0M4PXrc6BIF6nqpPR+xE2OOGj9hEv0mG6rWuQZDwXH6oMq8GD6P5iGp4F5WG0SfWwECFxhKwXgAjA==')}); return false;">
#                8 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_213351" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="99_book_43449920">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="8crFkFm6JNXatyXB1Q7vrYcKN7KAq0Llb8YeWgOyDS3g1GmduDilNig2RyOy+svuHf1ctnUnemp37mcCP+wWCw=="/>
#  <input id="book_id" name="book_id" type="hidden" value="43449920"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="99_book_43449920"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="5R4p61/owEltHktrGUXZfjE9wkrbVKLmg/+gzbOqeiP0AIXmvmpBqp+fKYl+sf09q8qpTi7Ymmmb19mVj/RhBQ=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="99_book_43449920"/>
#  <input id="book_id" name="book_id" type="hidden" value="43449920"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="43449920" data-restore-rating="null" data-submit-url="/review/rate/43449920?stars_click=true&amp;wtr_button_id=99_book_43449920" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>,
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">
#             100
#            </td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="56783258">
#  </div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="56783258" data-resource-type="Book">
#  <a href="/book/show/56783258-cloud-cuckoo-land" title="Cloud Cuckoo Land">
#  <img alt="Cloud Cuckoo Land" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1618589128i/56783258._SY75_.jpg"/>
#  </a>
#  </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/56783258-cloud-cuckoo-land" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">
#               Cloud Cuckoo Land
#              </span>
#  </a>
#  <br/>
#  <span class="by">
#              by
#             </span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
#  <a class="authorName" href="https://www.goodreads.com/author/show/28186.Anthony_Doerr" itemprop="url">
#  <span itemprop="name">
#                 Anthony Doerr
#                </span>
#  </a>
#  <span class="greyText">
#                (Goodreads Author)
#               </span>
#  </div>
#  </span>
#  <br/>
#  <div>
#  <span class="greyText smallText uitext">
#  <span class="minirating">
#  <span class="stars staticStars notranslate">
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p10" size="12x12">
#  </span>
#  <span class="staticStar p3" size="12x12">
#  </span>
#  </span>
#                4.27 avg rating — 146,282 ratings
#               </span>
#  </span>
#  </div>
#  <div style="margin-top: 5px">
#  <span class="smallText uitext">
#  <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">
#                score: 763
#               </a>
#               ,
#               <span class="greyText">
#                and
#               </span>
#  <a href="#" id="loading_link_452233" onclick="new Ajax.Request('/list/list_book/11538073', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_452233');$('loading_link_452233').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_452233').show();;Element.hide('loading_anim_452233');}, onLoading:function(request){;Element.show('loading_anim_452233');Element.hide('loading_link_452233')}, onSuccess:function(request){Element.hide('loading_anim_452233');Element.show('loading_link_452233');}, parameters:'authenticity_token=' + encodeURIComponent('5qRbaCuE8b+msoyLuBO+403PZO07vDsRU3SsTTD+nlH3uvdlygZwXFQz7mnf55qg1zgP6c4wA55LXNUVDKCFdw==')}); return false;">
#                8 people voted
#               </a>
#  <img alt="Loading trans" class="loading" id="loading_anim_452233" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#  </span>
#  </div>
#  </td>
#  <td width="130px">
#  <div class="wtrButtonContainer wtrSignedOut" id="100_book_56783258">
#  <div class="wtrUp wtrLeft">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="v0ZW//niExFTqBKrmWAHUS+q4k2m8aLliIVeGHN2LfGuWPryGGCS8qEpcEn+lCMStV2JSVN9mmqQrSdATyg21w=="/>
#  <input id="book_id" name="book_id" type="hidden" value="56783258"/>
#  <input id="name" name="name" type="hidden" value="to-read"/>
#  <input id="unique_id" name="unique_id" type="hidden" value="100_book_56783258"/>
#  <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
#  <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  <button class="wtrToRead" type="submit">
#  <span class="progressTrigger">
#                  Want to Read
#                 </span>
#  <span class="progressIndicator">
#                  saving…
#                 </span>
#  </button>
#  </form>
#  </div>
#  <div class="wtrRight wtrUp">
#  <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post">
#  <input name="utf8" type="hidden" value="✓"/>
#  <input name="authenticity_token" type="hidden" value="w75+P17OxyRHm/EiQr2EfPYoZPi8i/PK2Bxy/TTy9oLSoNIyv0xGx7Uak8AlSaA/bN8P/EkHy0XANAulCKztpA=="/>
#  <input id="unique_id" name="unique_id" type="hidden" value="100_book_56783258"/>
#  <input id="book_id" name="book_id" type="hidden" value="56783258"/>
#  <input id="a" name="a" type="hidden"/>
#  <input id="name" name="name" type="hidden"/>
#  <input id="from_choice" name="from_choice" type="hidden" value="false"/>
#  <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
#  <input id="page_url" name="page_url" type="hidden"/>
#  </form>
#  <button class="wtrShelfButton">
#  </button>
#  </div>
#  <div class="ratingStars wtrRating">
#  <div class="starsErrorTooltip hidden">
#                Error rating book. Refresh and try again.
#               </div>
#  <div class="myRating uitext greyText">
#                Rate this book
#               </div>
#  <div class="clearRating uitext">
#                Clear rating
#               </div>
#  <div class="stars" data-rating="0" data-resource-id="56783258" data-restore-rating="null" data-submit-url="/review/rate/56783258?stars_click=true&amp;wtr_button_id=100_book_56783258" data-user-id="0">
#  <a class="star off" href="#" ref="" title="did not like it">
#                 1 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was ok">
#                 2 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="liked it">
#                 3 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="really liked it">
#                 4 of 5 stars
#                </a>
#  <a class="star off" href="#" ref="" title="it was amazing">
#                 5 of 5 stars
#                </a>
#  </div>
#  </div>
#  </div>
#  </td>
#  </tr>]

# %%
for book in books:
    #book = soup.find(itemtype = 'http://schema.org/Book')
    titleTag = book.find(class_ = 'bookTitle')
    title = titleTag.get_text().strip()

    authorTag = book.find(class_ = 'authorName')
    author = authorTag.get_text().strip()
    bookInfo = [title, author]

    bookList.append(bookInfo)
print(bookList)
