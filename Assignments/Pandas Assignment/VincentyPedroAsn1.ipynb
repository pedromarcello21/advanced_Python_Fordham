# %% [markdown]
# # Pedro Vincenty - Assignment 1

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('chesterish')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
#Import Pandas Library
import pandas as pd

# %%
#Load csv and set Symbol Column as index
df = pd.read_csv("SP500_Constituents_20230101.csv",index_col = "Symbol")

# %%
#Display first row of data
df.iloc[0]
# Out:
# Security                                       3M
# SEC filings                               reports
# GICS Sector                           Industrials
# GICS Sub-Industry        Industrial Conglomerates
# Headquarters Location       Saint Paul, Minnesota
# Date first added                       1976-08-09
# CIK                                         66740
# Founded                                      1902
# Name: MMM, dtype: object

# %%
#Determine number of rows in dataframe
len(df)
# Out:
# 503

# %%
#Which columns have missing values?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, MMM to ZTS
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Security               503 non-null    object
#  1   SEC filings            503 non-null    object
#  2   GICS Sector            503 non-null    object
#  3   GICS Sub-Industry      503 non-null    object
#  4   Headquarters Location  503 non-null    object
#  5   Date first added       458 non-null    object
#  6   CIK                    503 non-null    int64
#  7   Founded                503 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 35.4+ KB

# %% [markdown]
# "Date first added" has missing values

# %%
#Show data about Apple Stock
df.loc["AAPL"]
# Out:
# Security                                                 Apple Inc.
# SEC filings                                                 reports
# GICS Sector                                  Information Technology
# GICS Sub-Industry        Technology Hardware, Storage & Peripherals
# Headquarters Location                         Cupertino, California
# Date first added                                         1982-11-30
# CIK                                                          320193
# Founded                                                        1977
# Name: AAPL, dtype: object

# %%
#Show Distinct Values for "GICS Sector" and number of stocks in each
df.groupby("GICS Sector")["GICS Sector"].count()
# Out:
# GICS Sector
# Communication Services    25
# Consumer Discretionary    56
# Consumer Staples          33
# Energy                    23
# Financials                67
# Health Care               63
# Industrials               70
# Information Technology    76
# Materials                 29
# Real Estate               31
# Utilities                 30
# Name: GICS Sector, dtype: int64

# %%
#Show Energy Stocks
dfRecent = df[df["GICS Sector"] == "Energy"].sort_values("Date first added", ascending = True)
dfRecent.dropna(subset = "Date first added", inplace = True)
dfRecent
# Out:
#                          Security SEC filings GICS Sector  \
# Symbol
# HAL                   Halliburton     reports      Energy
# CVX           Chevron Corporation     reports      Energy
# COP                ConocoPhillips     reports      Energy
# XOM                    ExxonMobil     reports      Energy
# SLB                  Schlumberger     reports      Energy
# WMB            Williams Companies     reports      Energy
# OXY          Occidental Petroleum     reports      Energy
# HES              Hess Corporation     reports      Energy
# MRO                  Marathon Oil     reports      Energy
# APA               APA Corporation     reports      Energy
# DVN                  Devon Energy     reports      Energy
# EOG                 EOG Resources     reports      Energy
# CTRA                      Coterra     reports      Energy
# PXD     Pioneer Natural Resources     reports      Energy
# OKE                         ONEOK     reports      Energy
# ...

# %%
#First Added
dfRecent.iloc[0]
# Out:
# Security                                    Halliburton
# SEC filings                                     reports
# GICS Sector                                      Energy
# GICS Sub-Industry        Oil & Gas Equipment & Services
# Headquarters Location                    Houston, Texas
# Date first added                             1957-03-04
# CIK                                               45012
# Founded                                            1919
# Name: HAL, dtype: object

# %%
#Recently added
dfRecent.iloc[-1]
# Out:
# Security                                    Targa Resources
# SEC filings                                         reports
# GICS Sector                                          Energy
# GICS Sub-Industry        Oil & Gas Storage & Transportation
# Headquarters Location                        Houston, Texas
# Date first added                                 2022-10-12
# CIK                                                 1389170
# Founded                                                2005
# Name: TRGP, dtype: object

# %%
#Symbol, Security, and Founded Data columns for stocks missing "Recently Added" criteria
dfMissing = df[df["Date first added"].isnull()]
dfMissing[["Security","Founded"]].sort_values("Founded",ascending = True)
# Out:
#                         Security           Founded
# Symbol
# STT     State Street Corporation              1792
# ED           Consolidated Edison              1823
# MCK                     McKesson              1833
# GLW                 Corning Inc.              1851
# FITB            Fifth Third Bank              1858
# HBAN       Huntington Bancshares              1866
# MET                      MetLife              1868
# NTRS              Northern Trust              1889
# GE              General Electric              1892
# WY                  Weyerhaeuser              1900
# ROK          Rockwell Automation              1903
# MCO          Moody's Corporation              1909
# WHR        Whirlpool Corporation              1911
# ETN            Eaton Corporation              1911
# NI                      NiSource              1912
# FCX             Freeport-McMoRan              1912
# SPGI                  S&P Global              1917
# ...
