# %%
from yahoo_fin import stock_info as si

# get the historical stock prices for Apple Inc. (AAPL) from the past year
prices = si.get_data('AAPL', start_date='01/01/2022', end_date='12/31/2022')

# print the first few rows of the dataframe
print(prices.head())
# Out:
#                   open        high         low       close    adjclose  \
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  180.683868
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.390701
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  173.645538
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.746811
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.915573
#
#                volume ticker
# 2022-01-03  104487900   AAPL
# 2022-01-04   99310400   AAPL
# 2022-01-05   94537600   AAPL
# 2022-01-06   96904000   AAPL
# 2022-01-07   86709100   AAPL

# %%
# Import relevant packages
import requests
import os
from dotenv import load_dotenv
import pandas as pd

# %%
# get a previously issued AlphaVantage API key from an .env file
# *Pedro's key name is 'alphaVantageKey'.  Key name varies by user

env_file = 'env_vars.env'
load_dotenv(env_file)
myAPIKey = os.getenv('alphaVantageKey')
#print(myAPIKey)

# %%
# Establish stock
symbol = 'RKLB'

# define the url where the web service is
API_URL = "https://www.alphavantage.co/query"

# define the details for the Alpha Vantage request (key/value pairs in a dictionary)
data = {
        "function": "TIME_SERIES_DAILY_ADJUSTED",
        "symbol": symbol,
        "outputsize": "full",
        "datatype": "json",
        "apikey": myAPIKey
       }

# %%
# Issue request to web service
response = requests.get(API_URL, data)
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
# Convert requested data from web service to a python dictionary
data = response.json()

# %%
# Create data frame from dictionary
time_series = (data['Time Series (Daily)'])
df = pd.DataFrame.from_dict(time_series)
dfRKLB = df.transpose()
dfRKLB.index.name = 'Date_Time'
dfRKLB
# Out:
#             1. open 2. high 3. low 4. close 5. adjusted close 6. volume  \
# Date_Time
# 2023-04-11     4.05    4.11   3.99     4.07              4.07   2785030
# 2023-04-10     3.73    4.01   3.72      4.0               4.0   4070698
# 2023-04-06     3.69    3.77   3.62     3.77              3.77   3058357
# 2023-04-05     3.87    3.88   3.65     3.67              3.67   4079666
# 2023-04-04    4.075   4.075   3.83     3.87              3.87   3308286
# ...             ...     ...    ...      ...               ...       ...
# 2021-08-30     10.5   10.51    9.8    10.03             10.03   2264954
# 2021-08-27  10.3141    10.5    9.5    10.35             10.35   2825007
# 2021-08-26     11.0   11.04   9.96     9.96              9.96   3293796
# 2021-08-25  11.5805    11.6   9.98    10.43             10.43   5599989
# 2021-08-24     11.3    11.9  11.11    11.57             11.57   1279000
#
#            7. dividend amount 8. split coefficient
# Date_Time
# 2023-04-11             0.0000                  1.0
# 2023-04-10             0.0000                  1.0
# 2023-04-06             0.0000                  1.0
# 2023-04-05             0.0000                  1.0
# 2023-04-04             0.0000                  1.0
# ...                       ...                  ...
# 2021-08-30             0.0000                  1.0
# 2021-08-27             0.0000                  1.0
# 2021-08-26             0.0000                  1.0
# 2021-08-25             0.0000                  1.0
# 2021-08-24             0.0000                  1.0
#
# [410 rows x 8 columns]

# %%
from yahoo_fin import options

# %%
dis_dates = options.get_expiration_dates("DIS")

# %%
dis_dates
# Out:
# ['April 14, 2023',
#  'April 21, 2023',
#  'April 28, 2023',
#  'May 5, 2023',
#  'May 12, 2023',
#  'May 19, 2023',
#  'May 26, 2023',
#  'June 16, 2023',
#  'July 21, 2023',
#  'September 15, 2023',
#  'October 20, 2023',
#  'January 19, 2024',
#  'June 21, 2024',
#  'January 17, 2025',
#  'June 20, 2025']

# %%
chain = options.get_options_chain("DIS")

# %%
chain["calls"]
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   DIS230414C00060000   2023-04-10 1:28PM EDT    60.0       40.50  37.70
# 1   DIS230414C00070000  2023-04-06 12:16PM EDT    70.0       29.86  27.65
# 2   DIS230414C00075000   2023-03-10 1:04PM EDT    75.0       19.77  24.85
# 3   DIS230414C00080000  2023-04-06 10:04AM EDT    80.0       18.83  17.80
# 4   DIS230414C00081000  2023-03-29 10:14AM EDT    81.0       15.05  16.80
# 5   DIS230414C00084000   2023-04-12 1:56PM EDT    84.0       15.31  13.80
# 6   DIS230414C00085000  2023-04-12 12:33PM EDT    85.0       14.70  12.80
# 7   DIS230414C00086000  2023-04-12 11:46AM EDT    86.0       14.05  11.80
# 8   DIS230414C00087000  2023-04-12 11:46AM EDT    87.0       13.05  10.80
# 9   DIS230414C00088000  2023-04-12 11:46AM EDT    88.0       12.05   9.80
# 10  DIS230414C00089000  2023-04-12 11:29AM EDT    89.0       10.77   8.80
# 11  DIS230414C00090000   2023-04-12 3:51PM EDT    90.0        7.86   7.90
# 12  DIS230414C00091000   2023-04-12 2:30PM EDT    91.0        8.10   6.90
# 13  DIS230414C00092000  2023-04-12 11:38AM EDT    92.0        7.65   5.95
# 14  DIS230414C00093000   2023-04-10 2:51PM EDT    93.0        7.66   4.95
# 15  DIS230414C00094000   2023-04-12 3:41PM EDT    94.0        4.04   4.00
# 16  DIS230414C00095000   2023-04-12 3:10PM EDT    95.0        3.47   3.05
# 17  DIS230414C00096000   2023-04-12 3:51PM EDT    96.0        2.16   2.25
# 18  DIS230414C00097000   2023-04-12 3:59PM EDT    97.0        1.51   1.52
# 19  DIS230414C00098000   2023-04-12 3:59PM EDT    98.0        0.90   0.87
# 20  DIS230414C00099000   2023-04-12 3:59PM EDT    99.0        0.46   0.44
# 21  DIS230414C00100000   2023-04-12 3:59PM EDT   100.0        0.21   0.21
# 22  DIS230414C00101000   2023-04-12 3:59PM EDT   101.0        0.10   0.09
# 23  DIS230414C00102000   2023-04-12 3:59PM EDT   102.0        0.05   0.04
# 24  DIS230414C00103000   2023-04-12 3:56PM EDT   103.0        0.03   0.02
# 25  DIS230414C00104000   2023-04-12 3:59PM EDT   104.0        0.02   0.02
# 26  DIS230414C00105000   2023-04-12 3:58PM EDT   105.0        0.02   0.01
# 27  DIS230414C00106000   2023-04-12 3:40PM EDT   106.0        0.01   0.01
# 28  DIS230414C00107000   2023-04-12 3:58PM EDT   107.0        0.01   0.01
# 29  DIS230414C00108000   2023-04-12 3:43PM EDT   108.0        0.01   0.00
# 30  DIS230414C00109000   2023-04-12 3:17PM EDT   109.0        0.01   0.00
# 31  DIS230414C00110000  2023-04-12 11:38AM EDT   110.0        0.01   0.00
# 32  DIS230414C00111000   2023-04-12 1:51PM EDT   111.0        0.01   0.00
# 33  DIS230414C00112000   2023-04-10 1:16PM EDT   112.0        0.01   0.00
# 34  DIS230414C00113000  2023-04-10 10:53AM EDT   113.0        0.01   0.00
# 35  DIS230414C00114000   2023-04-06 9:36AM EDT   114.0        0.03   0.00
# 36  DIS230414C00115000   2023-04-10 3:37PM EDT   115.0        0.01   0.00
# 37  DIS230414C00120000  2023-04-11 10:48AM EDT   120.0        0.01   0.00
# 38  DIS230414C00125000   2023-03-14 1:01PM EDT   125.0        0.01   0.00
# 39  DIS230414C00130000   2023-04-11 9:42AM EDT   130.0        0.01   0.00
# 40  DIS230414C00140000  2023-04-10 10:08AM EDT   140.0        0.01   0.00
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   38.20    0.00        -      2              1            193.75%
# 1   28.20    0.00        -      5              5            212.31%
# 2   25.30    0.00        -      -              1            307.03%
# 3   18.15    0.00        -      1              1             99.61%
# 4   17.15    0.00        -      -             10             94.53%
# 5   14.20    0.28   +1.86%      1              1             84.77%
# 6   13.15   -0.10   -0.68%      8             24             73.05%
# 7   12.15   -0.15   -1.06%      3             29             67.97%
# 8   11.15   -0.14   -1.06%      4             15             62.50%
# 9   10.20   -1.59  -11.66%      4             24             62.50%
# 10   9.20   -1.63  -13.15%      4             40             57.03%
# 11   8.15   -2.49  -24.06%      8             68             54.69%
# 12   7.10   -1.55  -16.06%     83             54             56.15%
# 13   6.10   -2.15  -21.94%      1            113             49.61%
# 14   5.15    0.00        -      4            196             46.29%
# 15   4.15   -3.26  -44.66%     10            399             39.26%
# 16   3.30   -2.59  -42.74%     21            397             38.67%
# 17   2.35   -2.71  -55.65%    108            457             32.03%
# 18   1.57   -2.19  -59.19%    181            448             29.30%
# 19   0.91   -1.87  -67.51%   1215            772             26.51%
# 20   0.48   -1.52  -76.77%   1025           1670             25.68%
# 21   0.24   -1.15  -84.56%   2792           3237             25.93%
# 22   0.10   -0.73  -87.95%   6709           4336             25.59%
# 23   0.05   -0.46  -90.20%   6378           6683             27.15%
# 24   0.03   -0.26  -89.66%   1963           1689             29.30%
# 25   0.03   -0.14  -87.50%   5809           8895             33.99%
# 26   0.02   -0.08  -80.00%    683           2445             35.94%
# 27   0.02   -0.05  -83.33%    363           2256             40.23%
# 28   0.02   -0.03  -75.00%     17            607             44.53%
# 29   0.01   -0.02  -66.67%    137           1066             43.75%
# 30   0.01   -0.01  -50.00%     96           1358             47.66%
# 31   0.02   -0.01  -50.00%    108            937             51.56%
# 32   0.02    0.00        -    109            245             54.69%
# 33   0.03    0.00        -     34            167             60.94%
# 34   0.03    0.00        -      5            146             64.84%
# 35   0.03    0.00        -      1              4             67.97%
# 36   0.01    0.00        -      9            268             62.50%
# 37   0.01    0.00        -      1             28             78.13%
# 38   0.01    0.00        -      3             37             93.75%
# 39   0.01    0.00        -      5              6            106.25%
# 40   0.01    0.00        -      2             12            131.25%
