# %%
import yahoo_fin.options as ops
import yahoo_fin.stock_info as si
import opstrat as op
import datetime

# %%
today = datetime.date.today()
formatted_date = today.strftime('%m/%d/%Y')
formatted_date
# Out:
# '04/27/2023'

# %%
expiration_dates = ops.get_expiration_dates("AAPL")
#expiration_dates

# %%
AAPLCalls = ops.get_calls("AAPL",expiration_dates[-3])
AAPLCalls.set_index("Contract Name",inplace = True)
#AAPLCalls

# %%
AAPLPuts = ops.get_puts("AAPL",expiration_dates[-3])
AAPLPuts.set_index("Contract Name",inplace = True)
AAPLPuts
# Out:
#                             Last Trade Date  Strike  Last Price     Bid  \
# Contract Name
# AAPL250117P00050000   2023-04-21 3:31PM EDT    50.0        0.40    0.33
# AAPL250117P00055000   2023-04-26 2:26PM EDT    55.0        0.61    0.38
# AAPL250117P00060000  2023-04-26 11:35AM EDT    60.0        0.80    0.52
# AAPL250117P00065000   2023-04-19 9:48AM EDT    65.0        0.92    0.68
# AAPL250117P00070000   2023-04-26 9:30AM EDT    70.0        1.20    1.10
# AAPL250117P00075000   2023-04-24 3:13PM EDT    75.0        1.38    1.12
# AAPL250117P00080000  2023-04-27 12:27PM EDT    80.0        1.74    1.39
# AAPL250117P00085000  2023-04-19 10:39AM EDT    85.0        1.97    1.95
# AAPL250117P00090000  2023-04-27 11:46AM EDT    90.0        2.47    2.27
# AAPL250117P00095000  2023-04-27 12:15PM EDT    95.0        2.89    2.71
# AAPL250117P00100000   2023-04-27 3:41PM EDT   100.0        3.35    3.25
# AAPL250117P00105000   2023-04-27 1:28PM EDT   105.0        4.05    3.80
# AAPL250117P00110000   2023-04-27 2:28PM EDT   110.0        4.60    4.45
# AAPL250117P00115000   2023-04-26 1:20PM EDT   115.0        5.82    5.20
# AAPL250117P00120000   2023-04-26 1:20PM EDT   120.0        6.20    6.00
# AAPL250117P00125000   2023-04-26 1:20PM EDT   125.0        7.73    6.95
# AAPL250117P00130000   2023-04-27 2:01PM EDT   130.0        8.23    7.95
# AAPL250117P00135000  2023-04-27 12:06PM EDT   135.0        9.51    9.10
# AAPL250117P00140000  2023-04-27 10:14AM EDT   140.0       10.95   10.30
# AAPL250117P00145000  2023-04-27 11:51AM EDT   145.0       12.31   11.70
# AAPL250117P00150000   2023-04-27 2:31PM EDT   150.0       13.45   13.15
# AAPL250117P00155000   2023-04-27 2:51PM EDT   155.0       15.10   14.80
# AAPL250117P00160000   2023-04-27 3:08PM EDT   160.0       16.80   16.55
# AAPL250117P00165000   2023-04-27 3:33PM EDT   165.0       18.60   18.45
# AAPL250117P00170000   2023-04-27 2:33PM EDT   170.0       20.90   20.25
# AAPL250117P00175000   2023-04-27 1:20PM EDT   175.0       23.60   22.75
# AAPL250117P00180000   2023-04-27 3:34PM EDT   180.0       25.54   24.10
# AAPL250117P00185000  2023-04-26 12:55PM EDT   185.0       30.24   27.15
# AAPL250117P00190000   2023-04-27 1:17PM EDT   190.0       31.80   30.70
# AAPL250117P00195000   2023-04-21 3:44PM EDT   195.0       36.43   33.75
# AAPL250117P00200000  2023-04-24 10:43AM EDT   200.0       39.55   34.65
# AAPL250117P00205000  2023-04-24 11:15AM EDT   205.0       43.20   40.15
# AAPL250117P00185000   28.40    0.00        -      2           1751
# AAPL250117P00190000   31.35   -1.05   -3.20%      5           1674
# AAPL250117P00195000   34.40    0.00        -      5            943
# AAPL250117P00200000   37.65    0.00        -      2           1800
# AAPL250117P00205000   41.20    0.00        -      4            374
# AAPL250117P00210000   44.95   -1.45   -3.08%      1             12
# AAPL250117P00215000   48.90    0.00        -    123             64
# AAPL250117P00220000   53.70    0.00        -      1             93
# AAPL250117P00225000   58.00    0.00        -      4              2
# AAPL250117P00230000   62.60    0.00        -      2              0
# AAPL250117P00235000   67.60    0.00        -      4              0
# AAPL250117P00240000   73.45    0.00        -      4              0
# AAPL250117P00245000   78.45    0.00        -      2              0
# AAPL250117P00250000   83.55    0.00        -      2              1
# AAPL250117P00255000  125.50    0.00        -     10              0
# AAPL250117P00260000   93.40    0.00        -      1              0
# AAPL250117P00265000  129.50    0.00        -      -              0
# AAPL250117P00270000  126.95    0.00        -   1000              0
# AAPL250117P00275000  108.45    0.00        -      2              0
# AAPL250117P00280000  128.55    0.00        -      8              0
# AAPL250117P00285000  157.50    0.00        -      2              0
# AAPL250117P00290000  123.05  -20.45  -14.12%      8              0
# AAPL250117P00300000  137.25    0.00        -     14              0
# AAPL250117P00310000  174.50    0.00        -      4              0
#
#                     Implied Volatility
# Contract Name
# AAPL250117P00050000             49.05%
# AAPL250117P00055000             46.80%
# AAPL250117P00060000             44.57%
# AAPL250117P00065000             43.35%
# AAPL250117P00070000             41.86%
# AAPL250117P00075000             40.49%
# AAPL250117P00080000             39.22%
# AAPL250117P00085000             37.95%
# AAPL250117P00090000             36.68%
# AAPL250117P00095000             34.99%
# AAPL250117P00100000             34.04%
# AAPL250117P00105000             33.15%
# AAPL250117P00110000             32.23%
# AAPL250117P00115000             31.60%
# AAPL250117P00120000             30.49%
# AAPL250117P00125000             30.16%
# AAPL250117P00130000             29.12%
# AAPL250117P00135000             28.04%
# AAPL250117P00140000             27.27%
# AAPL250117P00145000             26.54%
# AAPL250117P00150000             25.78%
# AAPL250117P00155000             25.03%
# AAPL250117P00160000             24.30%
# AAPL250117P00165000             23.55%
# AAPL250117P00170000             22.78%
# AAPL250117P00175000             22.50%
# AAPL250117P00180000             23.31%
# AAPL250117P00185000             20.54%
# AAPL250117P00190000             19.87%
# AAPL250117P00195000             19.07%
# AAPL250117P00200000             18.23%
# AAPL250117P00205000             17.48%
# AAPL250117P00210000             16.68%
# AAPL250117P00215000             15.83%
# AAPL250117P00220000             16.40%
# AAPL250117P00225000             15.66%
# AAPL250117P00230000             15.34%
# AAPL250117P00235000             16.13%
# AAPL250117P00240000             19.34%
# AAPL250117P00245000             20.14%
# AAPL250117P00250000             21.17%
# AAPL250117P00255000             67.74%
# AAPL250117P00260000             22.25%
# AAPL250117P00265000             62.92%
# AAPL250117P00270000             55.48%
# AAPL250117P00275000             24.46%
# AAPL250117P00280000             49.43%
# AAPL250117P00285000             75.65%
# AAPL250117P00290000             25.10%
# AAPL250117P00300000             36.13%
# AAPL250117P00310000             70.57%

# %% [markdown]
# ### Single Plot

# %%
AAPLCall = AAPLCalls.loc['AAPL250117C00160000']
AAPLCall
# Out:
# Last Trade Date       2023-04-27 3:40PM EDT
# Strike                                160.0
# Last Price                             34.7
# Bid                                   34.15
# Ask                                    34.9
# Change                                 3.54
# % Change                            +11.36%
# Volume                                  215
# Open Interest                          8923
# Implied Volatility                   35.72%
# Name: AAPL250117C00160000, dtype: object

# %%
AAPL_daily = si.get_data("AAPL", start_date="01/01/2023", end_date=today, index_as_date = True, interval="1d")
AAPL_today = dis_daily.iloc[-1]
AAPL_today
# Out:
# open        163.059998
# high        165.279999
# low         162.800003
# close       163.759995
# adjclose    163.759995
# volume        45425700
# ticker            AAPL
# Name: 2023-04-26 00:00:00, dtype: object

# %%
AAPLSpot = AAPL_today[3]
AAPLStrike = AAPLCall[1]

# %%
op.single_plotter(spot=disSpot, strike=disStrike, op_type='c', tr_type='s', op_pr=disneyCall[2])

# %% [markdown]
# ### Multi Plot (Portfolio)

# %%
AAPLPut = AAPLPuts.loc['AAPL250117P00140000']
AAPLPut
# Out:
# Last Trade Date       2023-04-27 10:14AM EDT
# Strike                                 140.0
# Last Price                             10.95
# Bid                                     10.3
# Ask                                    10.55
# Change                                 -0.49
# % Change                              -4.28%
# Volume                                  1263
# Open Interest                          13997
# Implied Volatility                    27.27%
# Name: AAPL250117P00140000, dtype: object

# %%
AAPLStrike1 = disneyPut[1]
AAPLStrike2 = disneyCall[1]

# %%
op1={'op_type': 'p', 'strike': disStrike1, 'tr_type': 's', 'op_pr': disneyCall[2]}
op2={'op_type': 'c', 'strike': disStrike2, 'tr_type': 'b', 'op_pr': disneyPut[2]}

op_list=[op1, op2]
op.multi_plotter(spot=disSpot, op_list=op_list)

# %% [markdown]
# ### Implied volatility

# %%
implied_volatility = AAPLCall[-1]
implied_volatility
# Out:
# '35.72%'

# %% [markdown]
# ### Option Price

# %%
AAPLCall[2]
# Out:
# 34.7

# %% [markdown]
# ### Profit / Loss

# %%
AAPLCall
# Out:
# Last Trade Date       2023-04-27 3:40PM EDT
# Strike                                160.0
# Last Price                             34.7
# Bid                                   34.15
# Ask                                    34.9
# Change                                 3.54
# % Change                            +11.36%
# Volume                                  215
# Open Interest                          8923
# Implied Volatility                   35.72%
# Name: AAPL250117C00160000, dtype: object

# %%
from optionprice import Option

ploss = {'Equity Market Price at Expiry': [AAPLStrike2-10,AAPLStrike2,AAPLStrike2+10,AAPLStrike2+20,
                                           AAPLStrike2+30,AAPLStrike2+40]}
noc = int(AAPLCall[-3]) #number of contracts bought/sold
sperc = 100*noc #100 shares per contract
df = pd.DataFrame(ploss, columns = ['Equity Market Price at Expiry','Profit/Loss'])
payoffs = []
for i in df['Equity Market Price at Expiry']:

# Calculate Option Payoffs
        payoff = ((i - AAPLStrike2) * sperc) - (AAPLCall[2]*sperc)
        payoffs.append(payoff)

# Create DataFrame
ploss['Profit/Loss']=payoffs
final=pd.DataFrame(ploss,columns=['Equity Market Price at Expiry','Profit/Loss']).set_index('Equity Market Price at Expiry')

final
# Out:
#                                Profit/Loss
# Equity Market Price at Expiry
# 150.0                            -961050.0
# 160.0                            -746050.0
# 170.0                            -531050.0
# 180.0                            -316050.0
# 190.0                            -101050.0
# 200.0                             113950.0
