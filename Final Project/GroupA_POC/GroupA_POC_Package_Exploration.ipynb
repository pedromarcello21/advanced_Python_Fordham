# %% [markdown]
# ### Group A
# ### Professor Groner
# ### Advanced Python for Finance
# ### 4/14/2023
# ### <center> Yahoo_fin Package Exploration <center>

# %%
#!pip install yahoo_fin

# %%
import yahoo_fin.options as ops
from yahoo_fin.stock_info import get_data
import yahoo_fin.stock_info as si

# %% [markdown]
# ### Stock Info

# %%
dis_min= get_data("dis", start_date="04/10/2023", end_date="04/14/2023", index_as_date = True, interval="1m")
dis_min
# Out:
#                            open        high         low       close    volume  \
# 2023-04-10 13:30:00   99.300003   99.320000   99.120003   99.120003   62322.0
# 2023-04-10 13:31:00   99.099998   99.169998   99.019997   99.050003  158062.0
# 2023-04-10 13:32:00   99.040001   99.089996   98.900002   98.959999   29254.0
# 2023-04-10 13:33:00   98.940002   99.059998   98.934502   99.050003   17361.0
# 2023-04-10 13:34:00   99.029999   99.089996   98.989998   99.080002   30846.0
# ...                         ...         ...         ...         ...       ...
# 2023-04-13 19:56:00  101.059998  101.065002  100.919998  100.930000  102845.0
# 2023-04-13 19:57:00  100.919998  100.940002  100.889999  100.940002   71276.0
# 2023-04-13 19:58:00  100.934998  100.940002  100.879997  100.885002  118289.0
# 2023-04-13 19:59:00  100.885002  100.889999  100.809998  100.849998  217586.0
# 2023-04-17 20:00:00  100.300003  100.300003  100.300003  100.300003       0.0
#
#                     ticker
# ...

# %%
# Obtain PE ratio
quote_table = si.get_quote_table("dis", dict_result=True)
quote_table
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/yahoo_fin/stock_info.py:295: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = tables[0].append(tables[1])
# /Applications/anaconda3/lib/python3.9/site-packages/yahoo_fin/stock_info.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(quote_price)
# {'1y Target Est': 125.52,
#  '52 Week Range': '84.07 - 133.19',
#  'Ask': '100.29 x 900',
#  'Avg. Volume': 10205973.0,
#  'Beta (5Y Monthly)': 1.3,
#  'Bid': '100.22 x 1000',
#  "Day's Range": '99.15 - 100.57',
#  'EPS (TTM)': 1.8,
#  'Earnings Date': 'May 10, 2023',
#  'Ex-Dividend Date': 'Dec 13, 2019',
#  'Forward Dividend & Yield': 'N/A (N/A)',
#  'Market Cap': '183.229B',
#  'Open': 99.57,
#  'PE Ratio (TTM)': 55.72,
#  'Previous Close': 99.9,
# ...

# %%
si.get_stats_valuation("dis")
# Out:
#                   Unnamed: 0 As of Date: 4/12/2023Current 12/31/2022  \
# 0      Market Cap (intraday)                      183.45B    158.43B
# 1           Enterprise Value                      223.35B    198.43B
# 2               Trailing P/E                        55.18      49.65
# 3                Forward P/E                        24.10      21.01
# 4  PEG Ratio (5 yr expected)                         1.05       0.70
# 5          Price/Sales (ttm)                         2.17       1.92
# 6           Price/Book (mrq)                         1.91       1.67
# 7   Enterprise Value/Revenue                         2.65       8.44
# 8    Enterprise Value/EBITDA                        18.27      55.99
#
#   9/30/2022 6/30/2022 3/31/2022
# 0   168.00B   171.95B   249.72B
# 1   206.64B   210.70B   289.41B
# 2     54.21     63.78     79.74
# 3     17.39     17.01     32.05
# 4      0.58      0.57      1.07
# 5      2.13      2.25      3.44
# 6      1.82      1.90      2.78
# ...

# %% [markdown]
# ### Options Information

# %%
# unable to get the expiration dates due to this error
# tried !pip install requests_html, but not successful
expiration_dates = ops.get_expiration_dates("dis")
expiration_dates
# Out:
# ['April 21, 2023',
#  'April 28, 2023',
#  'May 5, 2023',
#  'May 12, 2023',
#  'May 19, 2023',
#  'May 26, 2023',
#  'June 2, 2023',
#  'June 16, 2023',
#  'July 21, 2023',
#  'September 15, 2023',
#  'October 20, 2023',
#  'January 19, 2024',
#  'June 21, 2024',
#  'January 17, 2025',
#  'June 20, 2025']

# %%
# Get call options information on actual execution
ops.get_calls("dis")
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   DIS230421C00045000   2023-03-15 9:39AM EDT    45.0       47.40  53.65
# 1   DIS230421C00050000  2023-03-13 10:44AM EDT    50.0       42.40  49.50
# 2   DIS230421C00055000   2023-03-31 3:01PM EDT    55.0       44.70  45.00
# 3   DIS230421C00060000   2023-04-17 3:27PM EDT    60.0       40.12  40.00
# 4   DIS230421C00065000   2023-04-17 9:57AM EDT    65.0       34.90  35.05
# 5   DIS230421C00070000   2023-04-13 3:28PM EDT    70.0       30.88  30.05
# 6   DIS230421C00075000   2023-04-12 9:43AM EDT    75.0       26.65  25.25
# 7   DIS230421C00080000  2023-04-17 11:41AM EDT    80.0       19.97  20.25
# 8   DIS230421C00081000   2023-04-11 3:49PM EDT    81.0       19.55  19.20
# 9   DIS230421C00082000  2023-03-28 11:29AM EDT    82.0       13.95  18.25
# 10  DIS230421C00083000   2023-04-13 3:58PM EDT    83.0       18.10  17.30
# 11  DIS230421C00084000   2023-04-12 1:56PM EDT    84.0       15.43  16.30
# ...

# %%
# get put options for comparison purpose in later analysis
ops.get_puts("dis", "04/21/2023")
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   DIS230421P00045000   2023-03-29 1:09PM EDT    45.0        0.02   0.00
# 1   DIS230421P00050000   2023-04-11 9:40AM EDT    50.0        0.01   0.00
# 2   DIS230421P00055000   2023-03-15 2:57PM EDT    55.0        0.03   0.00
# 3   DIS230421P00060000   2023-04-13 9:47AM EDT    60.0        0.04   0.00
# 4   DIS230421P00065000  2023-04-17 10:15AM EDT    65.0        0.01   0.00
# 5   DIS230421P00070000  2023-04-17 10:15AM EDT    70.0        0.01   0.00
# 6   DIS230421P00075000   2023-04-17 2:52PM EDT    75.0        0.01   0.00
# 7   DIS230421P00080000   2023-04-17 1:56PM EDT    80.0        0.01   0.00
# 8   DIS230421P00081000   2023-04-17 9:50AM EDT    81.0        0.01   0.00
# 9   DIS230421P00082000  2023-04-14 10:53AM EDT    82.0        0.01   0.00
# 10  DIS230421P00083000  2023-04-14 10:53AM EDT    83.0        0.01   0.00
# 11  DIS230421P00084000   2023-04-17 3:33PM EDT    84.0        0.01   0.00
# ...
