# %% [markdown]
# # Pandas Case Study - S&P500 Stocks<br> Constituent Data

# %% [markdown]
# #### part A) load S&P500 stock data into a data frame; basic data review

# %%
import pandas as pd

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('chesterish')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #dbe1ea;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #a2b0c7;
#  padding: 8px 8px;
#  background: #252b35;
#  background-color: #252b35;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #2d3846;
#  background-color: #2d3846;
#  padding: 2px;
#  border-bottom: 2px solid rgba(75,95,118,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #2d3846;
#  background-color: #2d3846;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #0b98c8;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #4c8be2;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #009cd1;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #4c8be2;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #48a667 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #92a2bd !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #546386;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #a2b0c7;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid #252e3a;
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #009cd1;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #009cd1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #fefefe;
#  background-color: #a2b0c7;
#  background: #a2b0c7;
#  border-color: #a2b0c7;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1a2028;
#  background-color: #1a2028;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(75,95,118,.30);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #4c8be2;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: #252e3a !important;
#  background: #252e3a !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #dbe1ea;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(75,95,118,.10);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #a2b0c7;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-serif;
#  font-size: 13.5p

# %%
# read the data from a csv file into a DataFrame
asofdate = "20230101"
filename = "SP500_Constituents_"+asofdate+".csv"
dfsp = pd.read_csv(filename)

# %%
# display the first 10 rows of the DataFrame
dfsp.head(10)
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM                   3M     reports             Industrials
# 1    AOS          A. O. Smith     reports             Industrials
# 2    ABT               Abbott     reports             Health Care
# 3   ABBV               AbbVie     reports             Health Care
# 4    ACN            Accenture     reports  Information Technology
# 5   ATVI  Activision Blizzard     reports  Communication Services
# 6    ADM                  ADM     reports        Consumer Staples
# 7   ADBE           Adobe Inc.     reports  Information Technology
# 8    ADP                  ADP     reports  Information Technology
# 9    AAP   Advance Auto Parts     reports  Consumer Discretionary
#
#                        GICS Sub-Industry     Headquarters Location  \
# 0               Industrial Conglomerates     Saint Paul, Minnesota
# 1                      Building Products      Milwaukee, Wisconsin
# 2                  Health Care Equipment   North Chicago, Illinois
# 3                        Pharmaceuticals   North Chicago, Illinois
# 4         IT Consulting & Other Services           Dublin, Ireland
# 5         Interactive Home Entertainment  Santa Monica, California
# 6                  Agricultural Products         Chicago, Illinois
# 7                   Application Software      San Jose, California
# 8  Data Processing & Outsourced Services      Roseland, New Jersey
# 9                      Automotive Retail   Raleigh, North Carolina
#
#   Date first added      CIK      Founded
# 0       1976-08-09    66740         1902
# 1       2017-07-26    91142         1916
# 2       1964-03-31     1800         1888
# 3       2012-12-31  1551152  2013 (1888)
# 4       2011-07-06  1467373         1989
# 5       2015-08-31   718877         2008
# 6       1981-07-29     7084         1902
# 7       1997-05-05   796343         1982
# 8       1981-03-31     8670         1949
# 9       2015-07-09  1158449         1932

# %%
# check the number of rows of the DataFrame
len(dfsp)
# Out:
# 503

# %%
# check the columns and how many non-null values in each
dfsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 503 non-null    object
#  1   Security               503 non-null    object
#  2   SEC filings            503 non-null    object
#  3   GICS Sector            503 non-null    object
#  4   GICS Sub-Industry      503 non-null    object
#  5   Headquarters Location  503 non-null    object
#  6   Date first added       458 non-null    object
#  7   CIK                    503 non-null    int64
#  8   Founded                503 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.5+ KB

# %%
# A column can be accessed using [] notation
dfsp["Symbol"]
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
# The result of a [] access of column is a pandas Series
symbols = dfsp["Symbol"]
print(type(symbols))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Can get the values of a Series as a Python List using the tolist() method
print(symbols.tolist())
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FRC', 'FSLR', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SBNY', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VNO', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# %% [markdown]
# #### part B) Use ticker as the 'index' of the rows, since ticker is a unique key

# %%
# read data indicating that the Symbol column is to be the index (i.e., name for each row)
dfsp2 = pd.read_csv(filename,
                    index_col="Symbol", comment='#')

# %%
# note Symbol as row name is bolded below
dfsp2.head()
# Out:
#            Security SEC filings             GICS Sector  \
# Symbol
# MMM              3M     reports             Industrials
# AOS     A. O. Smith     reports             Industrials
# ABT          Abbott     reports             Health Care
# ABBV         AbbVie     reports             Health Care
# ACN       Accenture     reports  Information Technology
#
#                      GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM           Industrial Conglomerates    Saint Paul, Minnesota
# AOS                  Building Products     Milwaukee, Wisconsin
# ABT              Health Care Equipment  North Chicago, Illinois
# ABBV                   Pharmaceuticals  North Chicago, Illinois
# ACN     IT Consulting & Other Services          Dublin, Ireland
#
#        Date first added      CIK      Founded
# Symbol
# MMM          1976-08-09    66740         1902
# AOS          2017-07-26    91142         1916
# ABT          1964-03-31     1800         1888
# ABBV         2012-12-31  1551152  2013 (1888)
# ACN          2011-07-06  1467373         1989

# %%
# by default, Jupyter Notebook shows 1st and last 30 rows of a DataFrame
dfsp2
# Out:
#                     Security SEC filings             GICS Sector  \
# Symbol
# MMM                       3M     reports             Industrials
# AOS              A. O. Smith     reports             Industrials
# ABT                   Abbott     reports             Health Care
# ABBV                  AbbVie     reports             Health Care
# ACN                Accenture     reports  Information Technology
# ...                      ...         ...                     ...
# YUM              Yum! Brands     reports  Consumer Discretionary
# ZBRA      Zebra Technologies     reports  Information Technology
# ZBH            Zimmer Biomet     reports             Health Care
# ZION    Zions Bancorporation     reports              Financials
# ZTS                   Zoetis     reports             Health Care
#
#                          GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates    Saint Paul, Minnesota
# AOS                      Building Products     Milwaukee, Wisconsin
# ABT                  Health Care Equipment  North Chicago, Illinois
# ABBV                       Pharmaceuticals  North Chicago, Illinois
# ACN         IT Consulting & Other Services          Dublin, Ireland
# ...                                    ...                      ...
# YUM                            Restaurants     Louisville, Kentucky
# ZBRA    Electronic Equipment & Instruments   Lincolnshire, Illinois
# ZBH                  Health Care Equipment          Warsaw, Indiana
# ZION                        Regional Banks     Salt Lake City, Utah
# ZTS                        Pharmaceuticals   Parsippany, New Jersey
#
#        Date first added      CIK      Founded
# Symbol
# MMM          1976-08-09    66740         1902
# AOS          2017-07-26    91142         1916
# ABT          1964-03-31     1800         1888
# ABBV         2012-12-31  1551152  2013 (1888)
# ACN          2011-07-06  1467373         1989
# ...                 ...      ...          ...
# YUM          1997-10-06  1041061         1997
# ZBRA         2019-12-23   877212         1969
# ZBH          2001-08-07  1136869         1927
# ZION         2001-06-22   109380         1873
# ZTS          2013-06-21  1555280         1952
#
# [503 rows x 8 columns]

# %%
# use a row name to get data for a row (as a Series)
dfsp2.loc["AAPL"]
# Out:
# Security                                                 Apple Inc.
# SEC filings                                                 reports
# GICS Sector                                  Information Technology
# GICS Sub-Industry        Technology Hardware, Storage & Peripherals
# Headquarters Location                         Cupertino, California
# Date first added                                         1982-11-30
# CIK                                                          320193
# Founded                                                        1977
# Name: AAPL, dtype: object

# %%
# the values of a row, as a Python list
dfsp2.loc["AAPL"].tolist()
# Out:
# ['Apple Inc.',
#  'reports',
#  'Information Technology',
#  'Technology Hardware, Storage & Peripherals',
#  'Cupertino, California',
#  '1982-11-30',
#  320193,
#  '1977']

# %%
# access a cell value via df.loc[rowname][colname]
dfsp2.loc["MMM"]["GICS Sub-Industry"]
# Out:
# 'Industrial Conglomerates'

# %%
# access a cell value via df[colname][rowname]
dfsp2["GICS Sector"]["AAPL"]
# Out:
# 'Information Technology'

# %%
# check the type of a numeric cell
type(dfsp2["GICS Sector"]["AAPL"])
# Out:
# str

# %% [markdown]
# #### part C) Selection

# %%
# Filter on a string match
# what are the Technology companies in the SP500?
dfsp2[dfsp2["GICS Sector"] == "Information Technology"]
# Out:
#                   Security SEC filings             GICS Sector  \
# Symbol
# ACN              Accenture     reports  Information Technology
# ADBE            Adobe Inc.     reports  Information Technology
# ADP                    ADP     reports  Information Technology
# AKAM                Akamai     reports  Information Technology
# AMD                    AMD     reports  Information Technology
# ...                    ...         ...                     ...
# TYL     Tyler Technologies     reports  Information Technology
# VRSN              Verisign     reports  Information Technology
# V                Visa Inc.     reports  Information Technology
# WDC        Western Digital     reports  Information Technology
# ZBRA    Zebra Technologies     reports  Information Technology
#
#                                  GICS Sub-Industry      Headquarters Location  \
# Symbol
# ACN                 IT Consulting & Other Services            Dublin, Ireland
# ADBE                          Application Software       San Jose, California
# ADP          Data Processing & Outsourced Services       Roseland, New Jersey
# AKAM            Internet Services & Infrastructure   Cambridge, Massachusetts
# AMD                                 Semiconductors    Santa Clara, California
# ...                                            ...                        ...
# TYL                           Application Software               Plano, Texas
# VRSN            Internet Services & Infrastructure           Dulles, Virginia
# V            Data Processing & Outsourced Services  San Francisco, California
# WDC     Technology Hardware, Storage & Peripherals       San Jose, California
# ZBRA            Electronic Equipment & Instruments     Lincolnshire, Illinois
#
#        Date first added      CIK Founded
# Symbol
# ACN          2011-07-06  1467373    1989
# ADBE         1997-05-05   796343    1982
# ADP          1981-03-31     8670    1949
# AKAM         2007-07-12  1086222    1998
# AMD                 NaN     2488    1969
# ...                 ...      ...     ...
# TYL          2020-06-22   860731    1966
# VRSN         2006-02-01  1014473    1995
# V            2009-12-21  1403161    1958
# WDC          2009-07-01   106040    1970
# ZBRA         2019-12-23   877212    1969
#
# [76 rows x 8 columns]

# %%
# filter and set result to a variable
dfTech = dfsp2[dfsp2["GICS Sector"] == "Information Technology"]
dfTech
# Out:
#                   Security SEC filings             GICS Sector  \
# Symbol
# ACN              Accenture     reports  Information Technology
# ADBE            Adobe Inc.     reports  Information Technology
# ADP                    ADP     reports  Information Technology
# AKAM                Akamai     reports  Information Technology
# AMD                    AMD     reports  Information Technology
# ...                    ...         ...                     ...
# TYL     Tyler Technologies     reports  Information Technology
# VRSN              Verisign     reports  Information Technology
# V                Visa Inc.     reports  Information Technology
# WDC        Western Digital     reports  Information Technology
# ZBRA    Zebra Technologies     reports  Information Technology
#
#                                  GICS Sub-Industry      Headquarters Location  \
# Symbol
# ACN                 IT Consulting & Other Services            Dublin, Ireland
# ADBE                          Application Software       San Jose, California
# ADP          Data Processing & Outsourced Services       Roseland, New Jersey
# AKAM            Internet Services & Infrastructure   Cambridge, Massachusetts
# AMD                                 Semiconductors    Santa Clara, California
# ...                                            ...                        ...
# TYL                           Application Software               Plano, Texas
# VRSN            Internet Services & Infrastructure           Dulles, Virginia
# V            Data Processing & Outsourced Services  San Francisco, California
# WDC     Technology Hardware, Storage & Peripherals       San Jose, California
# ZBRA            Electronic Equipment & Instruments     Lincolnshire, Illinois
#
#        Date first added      CIK Founded
# Symbol
# ACN          2011-07-06  1467373    1989
# ADBE         1997-05-05   796343    1982
# ADP          1981-03-31     8670    1949
# AKAM         2007-07-12  1086222    1998
# AMD                 NaN     2488    1969
# ...                 ...      ...     ...
# TYL          2020-06-22   860731    1966
# VRSN         2006-02-01  1014473    1995
# V            2009-12-21  1403161    1958
# WDC          2009-07-01   106040    1970
# ZBRA         2019-12-23   877212    1969
#
# [76 rows x 8 columns]

# %%
# date filter (dates are YYYY-MM-DD string in this data)
# which companies were added to the SP500 during 2020?
dfsprecent = dfsp2[dfsp2["Date first added"] >= "2022-01-01"]
# include selected columns of interest
dfsprecent[["Security", "GICS Sector", "GICS Sub-Industry", "Date first added", "Founded"]]
# Out:
#                       Security             GICS Sector  \
# Symbol
# ACGL        Arch Capital Group              Financials
# CPT      Camden Property Trust             Real Estate
# CEG       Constellation Energy               Utilities
# CSGP              CoStar Group             Industrials
# EQT                        EQT                  Energy
# FSLR               First Solar  Information Technology
# INVH          Invitation Homes             Real Estate
# KDP           Keurig Dr Pepper        Consumer Staples
# MOH          Molina Healthcare             Health Care
# NDSN       Nordson Corporation             Industrials
# ON            ON Semiconductor  Information Technology
# PCG           PG&E Corporation               Utilities
# STLD            Steel Dynamics               Materials
# TRGP           Targa Resources                  Energy
# VICI           Vici Properties             Real Estate
# WBD     Warner Bros. Discovery  Communication Services
#
#                          GICS Sub-Industry Date first added Founded
# Symbol
# ACGL                           Reinsurance       2022-11-01    1995
# CPT                      Residential REITs       2022-04-04    1981
# CEG                        Multi-Utilities       2022-02-02    1999
# CSGP        Research & Consulting Services       2022-09-19    1987
# EQT     Oil & Gas Exploration & Production       2022-10-03    1888
# FSLR                        Semiconductors       2022-12-19    1999
# INVH                     Residential REITs       2022-09-19    2012
# KDP                            Soft Drinks       2022-06-21    1981
# MOH                    Managed Health Care       2022-03-02    1980
# NDSN                  Industrial Machinery       2022-02-15    1935
# ON                          Semiconductors       2022-06-21    1999
# PCG                        Multi-Utilities       2022-10-03    1905
# STLD                                 Steel       2022-12-22    1993
# TRGP    Oil & Gas Storage & Transportation       2022-10-12    2005
# VICI                  Hotel & Resort REITs       2022-06-08    2017
# WBD                           Broadcasting       2022-04-11    2022

# %%
# loop over rows of a DataFrame using for and .iterrows() method
for index, row in dfTech.iterrows():
    print(index, '\t', row.Security)
# Out:
# ACN 	 Accenture
# ADBE 	 Adobe Inc.
# ADP 	 ADP
# AKAM 	 Akamai
# AMD 	 AMD
# APH 	 Amphenol
# ADI 	 Analog Devices
# ANSS 	 Ansys
# AAPL 	 Apple Inc.
# AMAT 	 Applied Materials
# ANET 	 Arista Networks
# ADSK 	 Autodesk
# AVGO 	 Broadcom Inc.
# BR 	 Broadridge Financial Solutions
# CDNS 	 Cadence Design Systems
# CDW 	 CDW
# CDAY 	 Ceridian
# CSCO 	 Cisco
# CTSH 	 Cognizant
# GLW 	 Corning Inc.
# DXC 	 DXC Technology
# ENPH 	 Enphase
# EPAM 	 EPAM Systems
# FFIV 	 F5, Inc.
# FSLR 	 First Solar
# FIS 	 FIS
# FISV 	 Fiserv
# FLT 	 Fleetcor
# FTNT 	 Fortinet
# IT 	 Gartner
# GEN 	 Gen Digital Inc.
# GPN 	 Global Payments
# HPE 	 Hewlett Packard Enterprise
# HPQ 	 HP Inc.
# IBM 	 IBM
# INTC 	 Intel
# INTU 	 Intuit
# JKHY 	 Jack Henry & Associates
# JNPR 	 Juniper Networks
# KEYS 	 Keysight
# KLAC 	 KLA Corporation
# LRCX 	 Lam Research
# MA 	 Mastercard
# MCHP 	 Microchip Technology
# MU 	 Micron Technology
# MSFT 	 Microsoft
# MPWR 	 Monolithic Power Systems
# MSI 	 Motorola Solutions
# NTAP 	 NetApp
# NVDA 	 Nvidia
# NXPI 	 NXP Semiconductors
# ON 	 ON Semiconductor
# ORCL 	 Oracle Corporation
# PAYX 	 Paychex
# PAYC 	 Paycom
# PYPL 	 PayPal
# PTC 	 PTC
# QRVO 	 Qorvo
# QCOM 	 Qualcomm
# ROP 	 Roper Technologies
# CRM 	 Salesforce
# STX 	 Seagate Technology
# NOW 	 ServiceNow
# SWKS 	 Skyworks Solutions
# SEDG 	 SolarEdge
# SNPS 	 Synopsys
# TEL 	 TE Connectivity
# TDY 	 Teledyne Technologies
# TER 	 Teradyne
# TXN 	 Texas Instruments
# TRMB 	 Trimble Inc.
# TYL 	 Tyler Technologies
# VRSN 	 Verisign
# V 	 Visa Inc.
# WDC 	 Western Digital
# ZBRA 	 Zebra Technologies

# %% [markdown]
# #### part D)  drop data columns

# %%
# drop column (and create new DataFrame)
dfspNoSEC = dfsp2.drop(['SEC filings', 'CIK'],axis=1)
dfspNoSEC
# Out:
#                     Security             GICS Sector  \
# Symbol
# MMM                       3M             Industrials
# AOS              A. O. Smith             Industrials
# ABT                   Abbott             Health Care
# ABBV                  AbbVie             Health Care
# ACN                Accenture  Information Technology
# ...                      ...                     ...
# YUM              Yum! Brands  Consumer Discretionary
# ZBRA      Zebra Technologies  Information Technology
# ZBH            Zimmer Biomet             Health Care
# ZION    Zions Bancorporation              Financials
# ZTS                   Zoetis             Health Care
#
#                          GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates    Saint Paul, Minnesota
# AOS                      Building Products     Milwaukee, Wisconsin
# ABT                  Health Care Equipment  North Chicago, Illinois
# ABBV                       Pharmaceuticals  North Chicago, Illinois
# ACN         IT Consulting & Other Services          Dublin, Ireland
# ...                                    ...                      ...
# YUM                            Restaurants     Louisville, Kentucky
# ZBRA    Electronic Equipment & Instruments   Lincolnshire, Illinois
# ZBH                  Health Care Equipment          Warsaw, Indiana
# ZION                        Regional Banks     Salt Lake City, Utah
# ZTS                        Pharmaceuticals   Parsippany, New Jersey
#
#        Date first added      Founded
# Symbol
# MMM          1976-08-09         1902
# AOS          2017-07-26         1916
# ABT          1964-03-31         1888
# ABBV         2012-12-31  2013 (1888)
# ACN          2011-07-06         1989
# ...                 ...          ...
# YUM          1997-10-06         1997
# ZBRA         2019-12-23         1969
# ZBH          2001-08-07         1927
# ZION         2001-06-22         1873
# ZTS          2013-06-21         1952
#
# [503 rows x 6 columns]

# %%
# drop column (in place)
dfsp2.drop(['SEC filings'],axis=1,inplace=True)
dfsp2
# Out:
#                     Security             GICS Sector  \
# Symbol
# MMM                       3M             Industrials
# AOS              A. O. Smith             Industrials
# ABT                   Abbott             Health Care
# ABBV                  AbbVie             Health Care
# ACN                Accenture  Information Technology
# ...                      ...                     ...
# YUM              Yum! Brands  Consumer Discretionary
# ZBRA      Zebra Technologies  Information Technology
# ZBH            Zimmer Biomet             Health Care
# ZION    Zions Bancorporation              Financials
# ZTS                   Zoetis             Health Care
#
#                          GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates    Saint Paul, Minnesota
# AOS                      Building Products     Milwaukee, Wisconsin
# ABT                  Health Care Equipment  North Chicago, Illinois
# ABBV                       Pharmaceuticals  North Chicago, Illinois
# ACN         IT Consulting & Other Services          Dublin, Ireland
# ...                                    ...                      ...
# YUM                            Restaurants     Louisville, Kentucky
# ZBRA    Electronic Equipment & Instruments   Lincolnshire, Illinois
# ZBH                  Health Care Equipment          Warsaw, Indiana
# ZION                        Regional Banks     Salt Lake City, Utah
# ZTS                        Pharmaceuticals   Parsippany, New Jersey
#
#        Date first added      CIK      Founded
# Symbol
# MMM          1976-08-09    66740         1902
# AOS          2017-07-26    91142         1916
# ABT          1964-03-31     1800         1888
# ABBV         2012-12-31  1551152  2013 (1888)
# ACN          2011-07-06  1467373         1989
# ...                 ...      ...          ...
# YUM          1997-10-06  1041061         1997
# ZBRA         2019-12-23   877212         1969
# ZBH          2001-08-07  1136869         1927
# ZION         2001-06-22   109380         1873
# ZTS          2013-06-21  1555280         1952
#
# [503 rows x 7 columns]

# %% [markdown]
# #### part E) Sorting

# %%
# what are the oldest and newest companies in the SP500?
dfsp2.sort_values('Founded', ascending=True)
# Out:
#                         Security             GICS Sector  \
# Symbol
# BK                    BNY Mellon              Financials
# STT     State Street Corporation              Financials
# CL             Colgate-Palmolive        Consumer Staples
# HIG               Hartford (The)              Financials
# ED           Consolidated Edison               Utilities
# ...                          ...                     ...
# OTIS              Otis Worldwide             Industrials
# CARR              Carrier Global             Industrials
# OGN                Organon & Co.             Health Care
# CTRA                     Coterra                  Energy
# WBD       Warner Bros. Discovery  Communication Services
#
#                          GICS Sub-Industry        Headquarters Location  \
# Symbol
# BK        Asset Management & Custody Banks      New York City, New York
# STT       Asset Management & Custody Banks        Boston, Massachusetts
# CL                      Household Products      New York City, New York
# HIG          Property & Casualty Insurance        Hartford, Connecticut
# ED                      Electric Utilities      New York City, New York
# ...                                    ...                          ...
# OTIS                  Industrial Machinery      Farmington, Connecticut
# CARR                     Building Products  Palm Beach Gardens, Florida
# OGN                        Pharmaceuticals      Jersey City, New Jersey
# CTRA    Oil & Gas Exploration & Production               Houston, Texas
# WBD                           Broadcasting      New York City, New York
#
#        Date first added      CIK      Founded
# Symbol
# BK           1995-03-31  1390777         1784
# STT                 NaN    93751         1792
# CL           1957-03-04    21665         1806
# HIG          1957-03-04   874766         1810
# ED                  NaN  1047862         1823
# ...                 ...      ...          ...
# OTIS         2020-04-03  1781335  2020 (1853)
# CARR         2020-04-03  1783180  2020 (1915)
# OGN          2021-06-03  1821825         2021
# CTRA         2008-06-23   858470  2021 (1989)
# WBD          2022-04-11  1437107         2022
#
# [503 rows x 7 columns]

# %% [markdown]
# #### part F) Missing values

# %%
dfsp2[dfsp2["Date first added"].isna()]
# Out:
#                         Security             GICS Sector  \
# Symbol
# AMD                          AMD  Information Technology
# ED           Consolidated Edison               Utilities
# GLW                 Corning Inc.  Information Technology
# DHR          Danaher Corporation             Health Care
# DRI           Darden Restaurants  Consumer Discretionary
# D                Dominion Energy               Utilities
# ETN            Eaton Corporation             Industrials
# FITB            Fifth Third Bank              Financials
# FE                   FirstEnergy               Utilities
# BEN           Franklin Templeton              Financials
# FCX             Freeport-McMoRan               Materials
# GE              General Electric             Industrials
# HUM                       Humana             Health Care
# HBAN       Huntington Bancshares              Financials
# KLAC             KLA Corporation  Information Technology
# L              Loews Corporation              Financials
# MAR       Marriott International  Consumer Discretionary
# MCK                     McKesson             Health Care
# MET                      MetLife              Financials
# MCO          Moody's Corporation              Financials
# MS                Morgan Stanley              Financials
# MSI           Motorola Solutions  Information Technology
# NI                      NiSource               Utilities
# NTRS              Northern Trust              Financials
# OMC                Omnicom Group  Communication Services
# PARA            Paramount Global  Communication Services
# PAYX                     Paychex  Information Technology
# PNW                Pinnacle West               Utilities
# PPL              PPL Corporation               Utilities
# QCOM                    Qualcomm  Information Technology
# RTX        Raytheon Technologies             Industrials
# ROK          Rockwell Automation             Industrials
# SPGI                  S&P Global              Financials
# SRE                Sempra Energy               Utilities
# STT     State Street Corporation              Financials
# TROW               T. Rowe Price              Financials
# TPR               Tapestry, Inc.  Consumer Discretionary
# TXN            Texas Instruments  Information Technology
# USB                    U.S. Bank              Financials
# VLO                Valero Energy                  Energy
# WM              Waste Management             Industrials
# WAT           Waters Corporation             Health Care
# WRK                     WestRock               Materials
# WY                  Weyerhaeuser             Real Estate
# WHR        Whirlpool Corporation  Consumer Discretionary
#
#                             GICS Sub-Industry  \
# Symbol
# AMD                            Semiconductors
# ED                         Electric Utilities
# GLW                     Electronic Components
# DHR                     Health Care Equipment
# DRI                               Restaurants
# D                          Electric Utilities
# ETN         Electrical Components & Equipment
# FITB                           Regional Banks
# FE                         Electric Utilities
# BEN          Asset Management & Custody Banks
# FCX                                    Copper
# GE                   Industrial Conglomerates
# HUM                       Managed Health Care
# HBAN                           Regional Banks
# KLAC                  Semiconductor Equipment
# L                        Multi-line Insurance
# MAR            Hotels, Resorts & Cruise Lines
# MCK                  Health Care Distributors
# MET                   Life & Health Insurance
# MCO                Financial Exchanges & Data
# MS             Investment Banking & Brokerage
# MSI                  Communications Equipment
# NI                            Multi-Utilities
# NTRS         Asset Management & Custody Banks
# OMC                               Advertising
# PARA                   Movies & Entertainment
# PAYX    Data Processing & Outsourced Services
# PNW                           Multi-Utilities
# PPL                        Electric Utilities
# QCOM                           Semiconductors
# RTX                       Aerospace & Defense
# ROK         Electrical Components & Equipment
# SPGI               Financial Exchanges & Data
# SRE                           Multi-Utilities
# STT          Asset Management & Custody Banks
# TROW         Asset Management & Custody Banks
# TPR       Apparel, Accessories & Luxury Goods
# TXN                            Semiconductors
# USB                         Diversified Banks
# VLO            Oil & Gas Refining & Marketing
# WM        Environmental & Facilities Services
# WAT                  Health Care Distributors
# WRK                           Paper Packaging
# WY                          Specialized REITs
# WHR                      Household Appliances
#
#                     Headquarters Location Date first added      CIK  \
# Symbol
# AMD               Santa Clara, California              NaN     2488
# ED                New York City, New York              NaN  1047862
# GLW                     Corning, New York              NaN    24741
# DHR                      Washington, D.C.              NaN   313616
# DRI                      Orlando, Florida              NaN   940944
# D                      Richmond, Virginia              NaN   715957
# ETN                       Dublin, Ireland              NaN  1551182
# FITB                     Cincinnati, Ohio              NaN    35527
# FE                            Akron, Ohio              NaN  1031296
# BEN                 San Mateo, California              NaN    38777
# FCX                      Phoenix, Arizona              NaN   831259
# GE                  Boston, Massachusetts              NaN    40545
# HUM                  Louisville, Kentucky              NaN    49071
# HBAN    Columbus, Ohio; Detroit, Michigan              NaN    49196
# KLAC                 Milpitas, California              NaN   319201
# L                 New York City, New York              NaN    60086
# MAR                    Bethesda, Maryland              NaN  1048286
# MCK                         Irving, Texas              NaN   927653
# MET               New York City, New York              NaN  1099219
# MCO               New York City, New York              NaN  1059556
# MS                New York City, New York              NaN   895421
# MSI                     Chicago, Illinois              NaN    68505
# NI                  Merrillville, Indiana              NaN  1111711
# NTRS                    Chicago, Illinois              NaN    73124
# OMC               New York City, New York              NaN    29989
# PARA              New York City, New York              NaN   813828
# PAYX                   Penfield, New York              NaN   723531
# PNW                      Phoenix, Arizona              NaN   764622
# PPL               Allentown, Pennsylvania              NaN   922224
# QCOM                San Diego, California              NaN   804328
# RTX                Waltham, Massachusetts              NaN   101829
# ROK                  Milwaukee, Wisconsin              NaN  1024478
# SPGI              New York City, New York              NaN    64040
# SRE                 San Diego, California              NaN  1032208
# STT                 Boston, Massachusetts              NaN    93751
# TROW                  Baltimore, Maryland              NaN  1113169
# TPR               New York City, New York              NaN  1116132
# TXN                         Dallas, Texas              NaN    97476
# USB                Minneapolis, Minnesota              NaN    36104
# VLO                    San Antonio, Texas              NaN  1035002
# WM                         Houston, Texas              NaN   823768
# WAT                Milford, Massachusetts              NaN  1000697
# WRK                      Atlanta, Georgia              NaN  1732845
# WY                    Seattle, Washington              NaN   106535
# WHR               Benton Harbor, Michigan              NaN   106640
#
#                  Founded
# Symbol
# AMD                 1969
# ED                  1823
# GLW                 1851
# DHR                 1969
# DRI                 1938
# D                   1983
# ETN                 1911
# FITB                1858
# FE                  1997
# BEN                 1947
# FCX                 1912
# GE                  1892
# HUM                 1961
# HBAN                1866
# KLAC    1975/1977 (1997)
# L                   1959
# MAR                 1927
# MCK                 1833
# MET                 1868
# MCO                 1909
# MS                  1935
# MSI          1928 (2011)
# NI                  1912
# NTRS                1889
# OMC                 1986
# PARA         2019 (1952)
# PAYX                1971
# PNW                 1985
# PPL                 1920
# QCOM                1985
# RTX                 1922
# ROK                 1903
# SPGI                1917
# SRE                 1998
# STT                 1792
# TROW                1937
# TPR                 2017
# TXN                 1930
# USB                 1968
# VLO                 1980
# WM                  1968
# WAT                 1958
# WRK                 2015
# WY                  1900
# WHR                 1911

# %% [markdown]
# part G) Data augmentation

# %%
# determine year from a yyyy-mm-dd date
def yearFromDate(date):
    #print(date)
    if pd.isnull(date): return 0
    if len(date) != 10 or '-' not in date: return 0
    yyyy = date[:4]
    if not yyyy.isdigit(): return 0
    return int(yyyy)

# %%
yearFromDate('2020-01-01') # test above function
# Out:
# 2020

# %%
# augment data with the year first added
dfsp2["Year first added"] = dfsp2["Date first added"].apply(yearFromDate)
dfsp2
# Out:
#                     Security             GICS Sector  \
# Symbol
# MMM                       3M             Industrials
# AOS              A. O. Smith             Industrials
# ABT                   Abbott             Health Care
# ABBV                  AbbVie             Health Care
# ACN                Accenture  Information Technology
# ...                      ...                     ...
# YUM              Yum! Brands  Consumer Discretionary
# ZBRA      Zebra Technologies  Information Technology
# ZBH            Zimmer Biomet             Health Care
# ZION    Zions Bancorporation              Financials
# ZTS                   Zoetis             Health Care
#
#                          GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates    Saint Paul, Minnesota
# AOS                      Building Products     Milwaukee, Wisconsin
# ABT                  Health Care Equipment  North Chicago, Illinois
# ABBV                       Pharmaceuticals  North Chicago, Illinois
# ACN         IT Consulting & Other Services          Dublin, Ireland
# ...                                    ...                      ...
# YUM                            Restaurants     Louisville, Kentucky
# ZBRA    Electronic Equipment & Instruments   Lincolnshire, Illinois
# ZBH                  Health Care Equipment          Warsaw, Indiana
# ZION                        Regional Banks     Salt Lake City, Utah
# ZTS                        Pharmaceuticals   Parsippany, New Jersey
#
#        Date first added      CIK      Founded  Year first added
# Symbol
# MMM          1976-08-09    66740         1902              1976
# AOS          2017-07-26    91142         1916              2017
# ABT          1964-03-31     1800         1888              1964
# ABBV         2012-12-31  1551152  2013 (1888)              2012
# ACN          2011-07-06  1467373         1989              2011
# ...                 ...      ...          ...               ...
# YUM          1997-10-06  1041061         1997              1997
# ZBRA         2019-12-23   877212         1969              2019
# ZBH          2001-08-07  1136869         1927              2001
# ZION         2001-06-22   109380         1873              2001
# ZTS          2013-06-21  1555280         1952              2013
#
# [503 rows x 8 columns]
